# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("TaxiFare.csv")

# %%
df.head().style.background_gradient(cmap='ocean')
# Out:
# <style type="text/css">
# #T_71439_row0_col1, #T_71439_row0_col6, #T_71439_row0_col7, #T_71439_row1_col3, #T_71439_row1_col4, #T_71439_row1_col7, #T_71439_row2_col5, #T_71439_row3_col5, #T_71439_row3_col7, #T_71439_row4_col7 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_71439_row0_col3, #T_71439_row0_col5, #T_71439_row1_col1, #T_71439_row2_col7, #T_71439_row4_col4, #T_71439_row4_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_71439_row0_col4 {
#   background-color: #003c2d;
#   color: #f1f1f1;
# }
# #T_71439_row1_col5 {
#   background-color: #006214;
#   color: #f1f1f1;
# }
# #T_71439_row1_col6 {
#   background-color: #edf6f9;
#   color: #000000;
# }
# #T_71439_row2_col1 {
#   background-color: #005c18;
#   color: #f1f1f1;
# }
# #T_71439_row2_col3 {
#   background-color: #003631;
#   color: #f1f1f1;
# }
# #T_71439_row2_col4 {
#   background-color: #a5d2e1;
#   color: #000000;
# }
# #T_71439_row2_col6 {
#   background-color: #004e89;
#   color: #f1f1f1;
# }
# #T_71439_row3_col1 {
#   background-color: #001d42;
#   color: #f1f1f1;
# }
# #T_71439_row3_col3 {
#   background-color: #003f2b;
#   color: #f1f1f1;
# }
# #T_71439_row3_col4 {
#   background-color: #001362;
#   color: #f1f1f1;
# }
# #T_71439_row3_col6 {
#   background-color: #0076a4;
#   color: #f1f1f1;
# }
# #T_71439_row4_col1 {
#   background-color: #006810;
#   color: #f1f1f1;
# }
# #T_71439_row4_col3 {
#   background-color: #001547;
#   color: #f1f1f1;
# }
# #T_71439_row4_col5 {
#   background-color: #00273b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71439">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71439_level0_col0" class="col_heading level0 col0" >unique_id</th>
#       <th id="T_71439_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_71439_level0_col2" class="col_heading level0 col2" >date_time_of_pickup</th>
#       <th id="T_71439_level0_col3" class="col_heading level0 col3" >longitude_of_pickup</th>
#       <th id="T_71439_level0_col4" class="col_heading level0 col4" >latitude_of_pickup</th>
#       <th id="T_71439_level0_col5" class="col_heading level0 col5" >longitude_of_dropoff</th>
#       <th id="T_71439_level0_col6" class="col_heading level0 col6" >latitude_of_dropoff</th>
#       <th id="T_71439_level0_col7" class="col_heading level0 col7" >no_of_passenger</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71439_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71439_row0_col0" class="data row0 col0" >26:21.0</td>
#       <td id="T_71439_row0_col1" class="data row0 col1" >4.500000</td>
#       <td id="T_71439_row0_col2" class="data row0 col2" >2009-06-15 17:26:21 UTC</td>
#       <td id="T_71439_row0_col3" class="data row0 col3" >-73.844311</td>
#       <td id="T_71439_row0_col4" class="data row0 col4" >40.721319</td>
#       <td id="T_71439_row0_col5" class="data row0 col5" >-73.841610</td>
#       <td id="T_71439_row0_col6" class="data row0 col6" >40.712278</td>
#       <td id="T_71439_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_71439_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71439_row1_col0" class="data row1 col0" >52:16.0</td>
#       <td id="T_71439_row1_col1" class="data row1 col1" >16.900000</td>
#       <td id="T_71439_row1_col2" class="data row1 col2" >2010-01-05 16:52:16 UTC</td>
#       <td id="T_71439_row1_col3" class="data row1 col3" >-74.016048</td>
#       <td id="T_71439_row1_col4" class="data row1 col4" >40.711303</td>
#       <td id="T_71439_row1_col5" class="data row1 col5" >-73.979268</td>
#       <td id="T_71439_row1_col6" class="data row1 col6" >40.782004</td>
#       <td id="T_71439_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_71439_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71439_row2_col0" class="data row2 col0" >35:00.0</td>
#       <td id="T_71439_row2_col1" class="data row2 col1" >5.700000</td>
#       <td id="T_71439_row2_col2" class="data row2 col2" >2011-08-18 00:35:00 UTC</td>
#       <td id="T_71439_row2_col3" class="data row2 col3" >-73.982738</td>
#       <td id="T_71439_row2_col4" class="data row2 col4" >40.761270</td>
#       <td id="T_71439_row2_col5" class="data row2 col5" >-73.991242</td>
#       <td id="T_71439_row2_col6" class="data row2 col6" >40.750562</td>
#       <td id="T_71439_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_71439_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71439_row3_col0" class="data row3 col0" >30:42.0</td>
#       <td id="T_71439_row3_col1" class="data row3 col1" >7.700000</td>
#       <td id="T_71439_row3_col2" class="data row3 col2" >2012-04-21 04:30:42 UTC</td>
#       <td id="T_71439_row3_col3" class="data row3 col3" >-73.987130</td>
#       <td id="T_71439_row3_col4" class="data row3 col4" >40.733143</td>
#       <td id="T_71439_row3_col5" class="data row3 col5" >-73.991567</td>
#       <td id="T_71439_row3_col6" class="data row3 col6" >40.758092</td>
#       <td id="T_71439_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_71439_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71439_row4_col0" class="data row4 col0" >51:00.0</td>
#       <td id="T_71439_row4_col1" class="data row4 col1" >5.300000</td>
#       <td id="T_71439_row4_col2" class="data row4 col2" >2010-03-09 07:51:00 UTC</td>
#       <td id="T_71439_row4_col3" class="data row4 col3" >-73.968095</td>
#       <td id="T_71439_row4_col4" class="data row4 col4" >40.768008</td>
#       <td id="T_71439_row4_col5" class="data row4 col5" >-73.956655</td>
#       <td id="T_71439_row4_col6" class="data row4 col6" >40.783762</td>
#       <td id="T_71439_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.dtypes
# Out:
# unique_id                object
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_id             50000 non-null  object
#  1   amount                50000 non-null  float64
#  2   date_time_of_pickup   50000 non-null  object
#  3   longitude_of_pickup   50000 non-null  float64
#  4   latitude_of_pickup    50000 non-null  float64
#  5   longitude_of_dropoff  50000 non-null  float64
#  6   latitude_of_dropoff   50000 non-null  float64
#  7   no_of_passenger       50000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
# drop unique_id column
df.drop(['unique_id'],axis=1,inplace=True)

# %%
#df.head()

# %%
df.describe().style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_dcc6b_row0_col0, #T_dcc6b_row0_col1, #T_dcc6b_row0_col2, #T_dcc6b_row0_col3, #T_dcc6b_row0_col4, #T_dcc6b_row0_col5 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_dcc6b_row1_col0, #T_dcc6b_row1_col1, #T_dcc6b_row1_col2, #T_dcc6b_row1_col3, #T_dcc6b_row1_col4, #T_dcc6b_row1_col5, #T_dcc6b_row2_col0, #T_dcc6b_row2_col1, #T_dcc6b_row2_col2, #T_dcc6b_row2_col3, #T_dcc6b_row2_col4, #T_dcc6b_row2_col5, #T_dcc6b_row3_col0, #T_dcc6b_row3_col1, #T_dcc6b_row3_col2, #T_dcc6b_row3_col3, #T_dcc6b_row3_col4, #T_dcc6b_row3_col5, #T_dcc6b_row4_col0, #T_dcc6b_row4_col1, #T_dcc6b_row4_col2, #T_dcc6b_row4_col3, #T_dcc6b_row4_col4, #T_dcc6b_row4_col5, #T_dcc6b_row5_col0, #T_dcc6b_row5_col1, #T_dcc6b_row5_col2, #T_dcc6b_row5_col3, #T_dcc6b_row5_col4, #T_dcc6b_row5_col5, #T_dcc6b_row6_col0, #T_dcc6b_row6_col1, #T_dcc6b_row6_col2, #T_dcc6b_row6_col3, #T_dcc6b_row6_col4, #T_dcc6b_row6_col5, #T_dcc6b_row7_col1, #T_dcc6b_row7_col3, #T_dcc6b_row7_col4, #T_dcc6b_row7_col5 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_dcc6b_row7_col0 {
#   background-color: #01feff;
#   color: #000000;
# }
# #T_dcc6b_row7_col2 {
#   background-color: #02fdff;
#   color: #000000;
# }
# </style>
# <table id="T_dcc6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcc6b_level0_col0" class="col_heading level0 col0" >amount</th>
#       <th id="T_dcc6b_level0_col1" class="col_heading level0 col1" >longitude_of_pickup</th>
#       <th id="T_dcc6b_level0_col2" class="col_heading level0 col2" >latitude_of_pickup</th>
#       <th id="T_dcc6b_level0_col3" class="col_heading level0 col3" >longitude_of_dropoff</th>
#       <th id="T_dcc6b_level0_col4" class="col_heading level0 col4" >latitude_of_dropoff</th>
#       <th id="T_dcc6b_level0_col5" class="col_heading level0 col5" >no_of_passenger</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcc6b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_dcc6b_row0_col0" class="data row0 col0" >50000.000000</td>
#       <td id="T_dcc6b_row0_col1" class="data row0 col1" >50000.000000</td>
#       <td id="T_dcc6b_row0_col2" class="data row0 col2" >50000.000000</td>
#       <td id="T_dcc6b_row0_col3" class="data row0 col3" >50000.000000</td>
#       <td id="T_dcc6b_row0_col4" class="data row0 col4" >50000.000000</td>
#       <td id="T_dcc6b_row0_col5" class="data row0 col5" >50000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_dcc6b_row1_col0" class="data row1 col0" >11.364171</td>
#       <td id="T_dcc6b_row1_col1" class="data row1 col1" >-72.509756</td>
#       <td id="T_dcc6b_row1_col2" class="data row1 col2" >39.933759</td>
#       <td id="T_dcc6b_row1_col3" class="data row1 col3" >-72.504616</td>
#       <td id="T_dcc6b_row1_col4" class="data row1 col4" >39.926251</td>
#       <td id="T_dcc6b_row1_col5" class="data row1 col5" >1.667840</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_dcc6b_row2_col0" class="data row2 col0" >9.685557</td>
#       <td id="T_dcc6b_row2_col1" class="data row2 col1" >10.393860</td>
#       <td id="T_dcc6b_row2_col2" class="data row2 col2" >6.224857</td>
#       <td id="T_dcc6b_row2_col3" class="data row2 col3" >10.407570</td>
#       <td id="T_dcc6b_row2_col4" class="data row2 col4" >6.014737</td>
#       <td id="T_dcc6b_row2_col5" class="data row2 col5" >1.289195</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_dcc6b_row3_col0" class="data row3 col0" >-5.000000</td>
#       <td id="T_dcc6b_row3_col1" class="data row3 col1" >-75.423848</td>
#       <td id="T_dcc6b_row3_col2" class="data row3 col2" >-74.006893</td>
#       <td id="T_dcc6b_row3_col3" class="data row3 col3" >-84.654241</td>
#       <td id="T_dcc6b_row3_col4" class="data row3 col4" >-74.006377</td>
#       <td id="T_dcc6b_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_dcc6b_row4_col0" class="data row4 col0" >6.000000</td>
#       <td id="T_dcc6b_row4_col1" class="data row4 col1" >-73.992062</td>
#       <td id="T_dcc6b_row4_col2" class="data row4 col2" >40.734880</td>
#       <td id="T_dcc6b_row4_col3" class="data row4 col3" >-73.991152</td>
#       <td id="T_dcc6b_row4_col4" class="data row4 col4" >40.734372</td>
#       <td id="T_dcc6b_row4_col5" class="data row4 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_dcc6b_row5_col0" class="data row5 col0" >8.500000</td>
#       <td id="T_dcc6b_row5_col1" class="data row5 col1" >-73.981840</td>
#       <td id="T_dcc6b_row5_col2" class="data row5 col2" >40.752678</td>
#       <td id="T_dcc6b_row5_col3" class="data row5 col3" >-73.980082</td>
#       <td id="T_dcc6b_row5_col4" class="data row5 col4" >40.753372</td>
#       <td id="T_dcc6b_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_dcc6b_row6_col0" class="data row6 col0" >12.500000</td>
#       <td id="T_dcc6b_row6_col1" class="data row6 col1" >-73.967148</td>
#       <td id="T_dcc6b_row6_col2" class="data row6 col2" >40.767360</td>
#       <td id="T_dcc6b_row6_col3" class="data row6 col3" >-73.963584</td>
#       <td id="T_dcc6b_row6_col4" class="data row6 col4" >40.768167</td>
#       <td id="T_dcc6b_row6_col5" class="data row6 col5" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcc6b_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_dcc6b_row7_col0" class="data row7 col0" >200.000000</td>
#       <td id="T_dcc6b_row7_col1" class="data row7 col1" >40.783472</td>
#       <td id="T_dcc6b_row7_col2" class="data row7 col2" >401.083332</td>
#       <td id="T_dcc6b_row7_col3" class="data row7 col3" >40.851027</td>
#       <td id="T_dcc6b_row7_col4" class="data row7 col4" >43.415190</td>
#       <td id="T_dcc6b_row7_col5" class="data row7 col5" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - From the descriptive statistics of the data:
# - there are no missing values
# - And there are some outliers that needs to be treated
# -

# %%
# check the missing values
df.isna().sum()
# Out:
# amount                  0
# date_time_of_pickup     0
# longitude_of_pickup     0
# latitude_of_pickup      0
# longitude_of_dropoff    0
# latitude_of_dropoff     0
# no_of_passenger         0
# dtype: int64

# %%
df['month']=pd.to_datetime(df['date_time_of_pickup']).dt.month
df['day']=pd.to_datetime(df['date_time_of_pickup']).dt.day
df['year']=pd.to_datetime(df['date_time_of_pickup']).dt.year

# %%
# drop date_time_of_pickup
df.drop(['date_time_of_pickup'],axis=1, inplace=True)

# %%
# check duplicates
duplicate =df.duplicated()
print(duplicate.sum())
# Out:
# 0

# %%
df=df.drop_duplicates()

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.subplot(121)
sns.histplot(x=df['amount'],data=df, bins=20)
plt.subplot(122)
sns.boxplot(x=df['amount'], color='green')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most of the amount fall within the range of 0-60
# - there are alot of outliers in amount column

# %%
sns.histplot(x=df['year'],data=df, color='orange', bins=20)
plt.show()

# %%
sns.histplot(x=df['month'],data=df, color='indigo')
plt.show()

# %%
sns.histplot(x=df['no_of_passenger'],data=df, color='gray')

plt.show()

# %%
sns.scatterplot(x=df['no_of_passenger'],y=df['amount'])
plt.show()

# %% [markdown]
# - when the no. of passenger is 1, the amount is a little bit high

# %%
sns.scatterplot(x=df['year'],y=df['amount'])

plt.show()

# %% [markdown]
# #### Correlation between variable

# %%
cor= df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True, cmap='ocean',linewidths=3)
plt.show()

# %%
sns.pairplot(df,vars=['amount','day','year','month','no_of_passenger','latitude_of_dropoff'])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### create function to remove outliers

# %%
def remove_outlier(data):
    for col in data.columns:
        q1,q3 = data[col].quantile([0.25,0.75])
        iqr = q3-q1
        upper = q3+1.5*iqr
        lower = q1-1.5*iqr
        
        data[col]=np.where(data[col]>upper,upper,data[col])
        data[col]=np.where(data[col]<lower,lower,data[col])
        
    return data

# %%
df = remove_outlier(df)

# %%
df.describe().style.background_gradient(cmap='ocean')
# Out:
# <style type="text/css">
# #T_fba3a_row0_col0, #T_fba3a_row0_col1, #T_fba3a_row0_col2, #T_fba3a_row0_col3, #T_fba3a_row0_col4, #T_fba3a_row0_col5, #T_fba3a_row0_col6, #T_fba3a_row0_col7, #T_fba3a_row0_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_fba3a_row1_col0, #T_fba3a_row1_col1, #T_fba3a_row1_col2, #T_fba3a_row1_col3, #T_fba3a_row1_col4, #T_fba3a_row1_col5, #T_fba3a_row1_col6, #T_fba3a_row1_col7, #T_fba3a_row2_col0, #T_fba3a_row2_col1, #T_fba3a_row2_col2, #T_fba3a_row2_col3, #T_fba3a_row2_col4, #T_fba3a_row2_col5, #T_fba3a_row2_col6, #T_fba3a_row2_col7, #T_fba3a_row2_col8, #T_fba3a_row3_col0, #T_fba3a_row3_col1, #T_fba3a_row3_col2, #T_fba3a_row3_col3, #T_fba3a_row3_col4, #T_fba3a_row3_col5, #T_fba3a_row3_col6, #T_fba3a_row3_col7, #T_fba3a_row4_col0, #T_fba3a_row4_col1, #T_fba3a_row4_col2, #T_fba3a_row4_col3, #T_fba3a_row4_col4, #T_fba3a_row4_col5, #T_fba3a_row4_col6, #T_fba3a_row4_col7, #T_fba3a_row5_col0, #T_fba3a_row5_col1, #T_fba3a_row5_col2, #T_fba3a_row5_col3, #T_fba3a_row5_col4, #T_fba3a_row5_col5, #T_fba3a_row5_col6, #T_fba3a_row5_col7, #T_fba3a_row6_col0, #T_fba3a_row6_col1, #T_fba3a_row6_col2, #T_fba3a_row6_col3, #T_fba3a_row6_col4, #T_fba3a_row6_col5, #T_fba3a_row6_col6, #T_fba3a_row6_col7, #T_fba3a_row7_col0, #T_fba3a_row7_col1, #T_fba3a_row7_col2, #T_fba3a_row7_col3, #T_fba3a_row7_col4, #T_fba3a_row7_col5, #T_fba3a_row7_col6, #T_fba3a_row7_col7 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_fba3a_row1_col8, #T_fba3a_row3_col8, #T_fba3a_row4_col8, #T_fba3a_row5_col8, #T_fba3a_row6_col8, #T_fba3a_row7_col8 {
#   background-color: #00700a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fba3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fba3a_level0_col0" class="col_heading level0 col0" >amount</th>
#       <th id="T_fba3a_level0_col1" class="col_heading level0 col1" >longitude_of_pickup</th>
#       <th id="T_fba3a_level0_col2" class="col_heading level0 col2" >latitude_of_pickup</th>
#       <th id="T_fba3a_level0_col3" class="col_heading level0 col3" >longitude_of_dropoff</th>
#       <th id="T_fba3a_level0_col4" class="col_heading level0 col4" >latitude_of_dropoff</th>
#       <th id="T_fba3a_level0_col5" class="col_heading level0 col5" >no_of_passenger</th>
#       <th id="T_fba3a_level0_col6" class="col_heading level0 col6" >month</th>
#       <th id="T_fba3a_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_fba3a_level0_col8" class="col_heading level0 col8" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fba3a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_fba3a_row0_col0" class="data row0 col0" >49999.000000</td>
#       <td id="T_fba3a_row0_col1" class="data row0 col1" >49999.000000</td>
#       <td id="T_fba3a_row0_col2" class="data row0 col2" >49999.000000</td>
#       <td id="T_fba3a_row0_col3" class="data row0 col3" >49999.000000</td>
#       <td id="T_fba3a_row0_col4" class="data row0 col4" >49999.000000</td>
#       <td id="T_fba3a_row0_col5" class="data row0 col5" >49999.000000</td>
#       <td id="T_fba3a_row0_col6" class="data row0 col6" >49999.000000</td>
#       <td id="T_fba3a_row0_col7" class="data row0 col7" >49999.000000</td>
#       <td id="T_fba3a_row0_col8" class="data row0 col8" >49999.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_fba3a_row1_col0" class="data row1 col0" >10.107230</td>
#       <td id="T_fba3a_row1_col1" class="data row1 col1" >-73.978298</td>
#       <td id="T_fba3a_row1_col2" class="data row1 col2" >40.750267</td>
#       <td id="T_fba3a_row1_col3" class="data row1 col3" >-73.976011</td>
#       <td id="T_fba3a_row1_col4" class="data row1 col4" >40.750479</td>
#       <td id="T_fba3a_row1_col5" class="data row1 col5" >1.504650</td>
#       <td id="T_fba3a_row1_col6" class="data row1 col6" >6.273265</td>
#       <td id="T_fba3a_row1_col7" class="data row1 col7" >15.671873</td>
#       <td id="T_fba3a_row1_col8" class="data row1 col8" >2011.739295</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_fba3a_row2_col0" class="data row2 col0" >5.464407</td>
#       <td id="T_fba3a_row2_col1" class="data row2 col1" >0.020516</td>
#       <td id="T_fba3a_row2_col2" class="data row2 col2" >0.025702</td>
#       <td id="T_fba3a_row2_col3" class="data row2 col3" >0.022835</td>
#       <td id="T_fba3a_row2_col4" class="data row2 col4" >0.028529</td>
#       <td id="T_fba3a_row2_col5" class="data row2 col5" >0.867913</td>
#       <td id="T_fba3a_row2_col6" class="data row2 col6" >3.461183</td>
#       <td id="T_fba3a_row2_col7" class="data row2 col7" >8.660795</td>
#       <td id="T_fba3a_row2_col8" class="data row2 col8" >1.862641</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_fba3a_row3_col0" class="data row3 col0" >-3.750000</td>
#       <td id="T_fba3a_row3_col1" class="data row3 col1" >-74.029429</td>
#       <td id="T_fba3a_row3_col2" class="data row3 col2" >40.686161</td>
#       <td id="T_fba3a_row3_col3" class="data row3 col3" >-74.032503</td>
#       <td id="T_fba3a_row3_col4" class="data row3 col4" >40.683683</td>
#       <td id="T_fba3a_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_fba3a_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_fba3a_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_fba3a_row3_col8" class="data row3 col8" >2009.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_fba3a_row4_col0" class="data row4 col0" >6.000000</td>
#       <td id="T_fba3a_row4_col1" class="data row4 col1" >-73.992062</td>
#       <td id="T_fba3a_row4_col2" class="data row4 col2" >40.734881</td>
#       <td id="T_fba3a_row4_col3" class="data row4 col3" >-73.991152</td>
#       <td id="T_fba3a_row4_col4" class="data row4 col4" >40.734374</td>
#       <td id="T_fba3a_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_fba3a_row4_col6" class="data row4 col6" >3.000000</td>
#       <td id="T_fba3a_row4_col7" class="data row4 col7" >8.000000</td>
#       <td id="T_fba3a_row4_col8" class="data row4 col8" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_fba3a_row5_col0" class="data row5 col0" >8.500000</td>
#       <td id="T_fba3a_row5_col1" class="data row5 col1" >-73.981840</td>
#       <td id="T_fba3a_row5_col2" class="data row5 col2" >40.752679</td>
#       <td id="T_fba3a_row5_col3" class="data row5 col3" >-73.980083</td>
#       <td id="T_fba3a_row5_col4" class="data row5 col4" >40.753372</td>
#       <td id="T_fba3a_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_fba3a_row5_col6" class="data row5 col6" >6.000000</td>
#       <td id="T_fba3a_row5_col7" class="data row5 col7" >16.000000</td>
#       <td id="T_fba3a_row5_col8" class="data row5 col8" >2012.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_fba3a_row6_col0" class="data row6 col0" >12.500000</td>
#       <td id="T_fba3a_row6_col1" class="data row6 col1" >-73.967151</td>
#       <td id="T_fba3a_row6_col2" class="data row6 col2" >40.767361</td>
#       <td id="T_fba3a_row6_col3" class="data row6 col3" >-73.963584</td>
#       <td id="T_fba3a_row6_col4" class="data row6 col4" >40.768167</td>
#       <td id="T_fba3a_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_fba3a_row6_col6" class="data row6 col6" >9.000000</td>
#       <td id="T_fba3a_row6_col7" class="data row6 col7" >23.000000</td>
#       <td id="T_fba3a_row6_col8" class="data row6 col8" >2013.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fba3a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_fba3a_row7_col0" class="data row7 col0" >22.250000</td>
#       <td id="T_fba3a_row7_col1" class="data row7 col1" >-73.929783</td>
#       <td id="T_fba3a

# %%
for i in df.columns:
    sns.boxplot(x=i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 for i in df.columns:
# ----> 2     sns.boxplot(x=i)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'amount'
