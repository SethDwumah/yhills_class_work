# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets/CardioGoodFitness-1.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df['Fitness'].unique()
# Out:
# array([4, 3, 2, 1, 5], dtype=int64)

# %%
df['Usage'].unique()
# Out:
# array([3, 2, 4, 5, 6, 7], dtype=int64)

# %%
sum_of_income_by_age = df[['Income']].groupby(df['Age']).sum().plot()
sum_of_income_by_age
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
plt.figure('figure.size'==(5,5))
sns.countplot(df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure('figure.size'==(5,5))
sns.countplot(df['MaritalStatus'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
plt.figure('figure.size'==(5,5))
sns.countplot(df['Fitness'])
# Out:
# <AxesSubplot:xlabel='Fitness', ylabel='count'>

# %%
plt.figure('figure.size'==(5,5))
sns.histplot(df['Age'], kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure('figure.size'==(5,5))
sns.scatterplot(df['Age'],df['Income'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
plt.figure('figure.size'==(5,5))
sns.scatterplot(df['Age'],df['Income'],hue=df['MaritalStatus'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
plt.figure('figure.size'==(5,5))
sns.scatterplot(df['Education'],df['Income'],hue=df['Gender'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.scatterplot(df['Education'],df['Income'],hue=df['MaritalStatus'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.barplot(df['Education'],df['Income'],hue=df['Gender'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.barplot(df['Usage'],df['Income'],hue=df['Gender'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.countplot(df['Education'])
plt.show()

# %%
sns.pairplot(df, hue='Gender')
plt.show()

# %%
sns.pairplot(df, hue='MaritalStatus')
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.scatterplot(df['Miles'],df['Income'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.histplot(df['Income'])
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.boxplot(df['Income'],color='pink')
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.boxplot(df['Miles'],color='pink')
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.boxplot(df['Usage'],color='skyblue')
plt.show()

# %%
plt.figure('figure.size'==(5,5))
sns.boxplot(df['Age'],color='green')
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure('figure.size'==(5,5))
sns.histplot(df['Miles'],color='orange')
plt.show()
